# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----------- ---------------------------- 2.4/8.0 MB 12.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.0 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 11.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Sales Analysis

# %%
sales_data = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul','Aug','Sep','Oct','Nov','Dec'],
    'Sales': [100, 500, 200, 280, 389, 320,395,420,480,410,460,300],
    'Order_Quantity': [50, 65, 55, 70, 75, 80,85,90,95,100,110,120]
})

# %% [markdown]
# # Line plot for monthly sales

# %%
plt.figure(figsize=(10, 5))
plt.plot(sales_data['Month'], sales_data['Sales'], marker='o', linestyle='-', color='black')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# # Histogram for order quantity distribution

# %%
plt.figure(figsize=(10, 5))
plt.hist(sales_data['Order_Quantity'], bins=5, color='lightblue', edgecolor='black')
plt.title('Order Quantity Distribution')
plt.xlabel('Order Quantity')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # 2. Customer Demographics

# %%
customer_data = pd.DataFrame({
    'Age': [25, 30, 22, 45, 33, 29, 40, 50, 38, 28],
    'Spending_Score': [70, 65, 80, 55, 60, 75, 58, 40, 62, 78]
})

# %% [markdown]
# # Histogram for age distribution

# %%
plt.figure(figsize=(10, 5))
plt.hist(customer_data['Age'], bins=5, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Scatter plot for spending patterns

# %%
plt.figure(figsize=(10, 5))
plt.scatter(customer_data['Age'], customer_data['Spending_Score'], color='purple', alpha=0.7)
plt.title('Spending Patterns by Age')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.grid(True)
plt.show()

# %% [markdown]
# # 3. School Performance

# %%
school_data = pd.DataFrame({
    'Student': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve'],
    'Math': [85, 78, 92, 88, 76],
    'Science': [90, 85, 89, 94, 80],
    'English': [78, 83, 88, 82, 75]
})

# %% [markdown]
# # Bar chart for marks comparison across subjects

# %%
school_data.set_index('Student')[['Math', 'Science', 'English']].plot(kind='bar', figsize=(10, 5))
plt.title('Students Performance Across Subjects')
plt.xlabel('Students')
plt.ylabel('Marks')
plt.legend(title='Subjects')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Box plot to identify outliers

# %%
plt.figure(figsize=(10, 5))
school_data[['Math', 'Science', 'English']].plot(kind='box')
plt.title('Marks Distribution Across Subjects')
plt.ylabel('Marks')
plt.grid(True)
plt.show()
